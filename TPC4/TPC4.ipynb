# %%
import random

print('''Menu:\n1. Criar Lista\n2. Ler Lista\n3. Soma\n4. Média
5. Maior\n6. Menor\n7. Está ordenado por ordem crescente
8. Está ordenado por ordem decrescente\n9. Procura um elemento\n0. Sair''')

n = int (input ("Introduza um número de 0 a 9, de acordo com as funcionalidades do menu:"))

Lista = [1,2,3,4,5]

while n != 0:

    if n == 1:
        Lista.clear()
        m = int (input ("Introduza o número de elementos:"))
        Lista = []
        while len(Lista) < m:
            elem = random.randrange(1, 101)
            Lista.append(elem)
        print(Lista)
        print('''Menu:\n1. Criar Lista\n2. Ler Lista\n3. Soma\n4. Média
5. Maior\n6. Menor\n7. Está ordenado por ordem crescente
8. Está ordenado por ordem decrescente\n9. Procura um elemento\n0. Sair''')
        n = int (input ("Selecione a próxima funcionalidade que prentende aceder:"))

    elif n == 2:
        Lista.clear()
        Lista = []
        m = int (input ("Introduza o número de elemntos da lista:"))
        i = 1
        while len(Lista) < m:
            elem = int (input ("Intruza o elemento " + str(i) + ": "))
            Lista.append(elem)
            i = i + 1
        print(Lista)
        print('''Menu:\n1. Criar Lista\n2. Ler Lista\n3. Soma\n4. Média
5. Maior\n6. Menor\n7. Está ordenado por ordem crescente
8. Está ordenado por ordem decrescente\n9. Procura um elemento\n0. Sair''')
        n = int (input ("Selecione a próxima funcionalidade que prentende aceder:"))
    
    elif n == 3:
        Soma = 0
        for m in Lista:
            Soma = Soma + m
        print("A soma dos números",Lista,"é",Soma)
        print('''Menu:\n1. Criar Lista\n2. Ler Lista\n3. Soma\n4. Média
5. Maior\n6. Menor\n7. Está ordenado por ordem crescente
8. Está ordenado por ordem decrescente\n9. Procura um elemento\n0. Sair''')
        n = int (input ("Selecione a próxima funcionalidade que prentende aceder:"))
    
    elif n == 4:
        Soma = 0
        Media = 0
        for m in Lista:
            Soma = Soma + m
            Media = Soma/len(Lista)
        print("A média dos números",Lista,"é",Media)
        print('''Menu:\n1. Criar Lista\n2. Ler Lista\n3. Soma\n4. Média
5. Maior\n6. Menor\n7. Está ordenado por ordem crescente
8. Está ordenado por ordem decrescente\n9. Procura um elemento\n0. Sair''')
        n = int (input ("Selecione a próxima funcionalidade que prentende aceder:"))

    elif n == 5:
        Maior = Lista[0]
        for m in Lista:
            if m > Maior:
                Maior = m
        print("O maior número da lista",Lista,"é o",Maior)
        print('''Menu:\n1. Criar Lista\n2. Ler Lista\n3. Soma\n4. Média
5. Maior\n6. Menor\n7. Está ordenado por ordem crescente
8. Está ordenado por ordem decrescente\n9. Procura um elemento\n0. Sair''')
        n = int (input ("Selecione a próxima funcionalidade que prentende aceder:"))

    elif n == 6:
        Menor = Lista[0]
        for m in Lista:
            if m < Menor:
                Menor = m
        print("O menor número da lista",Lista,"é o",Menor)
        print('''Menu:\n1. Criar Lista\n2. Ler Lista\n3. Soma\n4. Média
5. Maior\n6. Menor\n7. Está ordenado por ordem crescente
8. Está ordenado por ordem decrescente\n9. Procura um elemento\n0. Sair''')
        n = int (input ("Selecione a próxima funcionalidade que prentende aceder:"))
    
    elif n == 7:
        Lista1 = Lista.copy()
        Lista1.sort()
        if Lista == Lista1:
            print("Sim")
        else:
            print("Não")
        print('''Menu:\n1. Criar Lista\n2. Ler Lista\n3. Soma\n4. Média
5. Maior\n6. Menor\n7. Está ordenado por ordem crescente
8. Está ordenado por ordem decrescente\n9. Procura um elemento\n0. Sair''')
        n = int (input ("Selecione a próxima funcionalidade que prentende aceder:"))

    elif n == 8:
        Lista2 = Lista.copy()
        Lista2.sort()
        Lista2.reverse()
        if Lista == Lista2:
            print("Sim")
        else:
            print("Não")
        print('''Menu:\n1. Criar Lista\n2. Ler Lista\n3. Soma\n4. Média
5. Maior\n6. Menor\n7. Está ordenado por ordem crescente
8. Está ordenado por ordem decrescente\n9. Procura um elemento\n0. Sair''')
        n = int (input ("Selecione a próxima funcionalidade que prentende aceder:"))
    
    elif n == 9:
        m = int (input ("Introduza o elemento que pretende procurar na lista:"))
        if m in Lista:
            Posição = Lista.index(m)
            print("O elemento",m,"encontra-se na posição",Posição,".")
        else:
            print("-1")
        print('''Menu:\n1. Criar Lista\n2. Ler Lista\n3. Soma\n4. Média
5. Maior\n6. Menor\n7. Está ordenado por ordem crescente
8. Está ordenado por ordem decrescente\n9. Procura um elemento\n0. Sair''')
        n = int (input ("Selecione a próxima funcionalidade que prentende aceder:"))

print(Lista)
# Out:
# Menu:
# 1. Criar Lista
# 2. Ler Lista
# 3. Soma
# 4. Média
# 5. Maior
# 6. Menor
# 7. Está ordenado por ordem crescente
# 8. Está ordenado por ordem decrescente
# 9. Procura um elemento
# 0. Sair
# [6, 99, 52, 61, 56]
# Menu:
# 1. Criar Lista
# 2. Ler Lista
# 3. Soma
# 4. Média
# 5. Maior
# 6. Menor
# 7. Está ordenado por ordem crescente
# 8. Está ordenado por ordem decrescente
# 9. Procura um elemento
# 0. Sair
# [4, 9, 68, 5, 3]
# Menu:
# 1. Criar Lista
# 2. Ler Lista
# 3. Soma
# 4. Média
# 5. Maior
# 6. Menor
# 7. Está ordenado por ordem crescente
# 8. Está ordenado por ordem decrescente
# 9. Procura um elemento
# 0. Sair
# A soma dos números [4, 9, 68, 5, 3] é 89
# Menu:
# 1. Criar Lista
# 2. Ler Lista
# 3. Soma
# 4. Média
# 5. Maior
# 6. Menor
# 7. Está ordenado por ordem crescente
# 8. Está ordenado por ordem decrescente
# 9. Procura um elemento
# 0. Sair
# A média dos números [4, 9, 68, 5, 3] é 17.8
# Menu:
# 1. Criar Lista
# 2. Ler Lista
# 3. Soma
# 4. Média
# 5. Maior
# ...
